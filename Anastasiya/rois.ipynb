# %%
from nilearn import plotting, image
import nibabel as nib
import os
import numpy as np
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %%
# %run loading_data.ipynb
sub_data = load_txt(n=200)
unrestricted_data = load_unrestricted()
restricted_data = load_restricted()
atlas = load_atlas(n=200)
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data
#
# Subject Data Loaded
# unrestricted_data loaded
# restricted_data loaded
# /tmp/ipykernel_4727/1030149754.py:16: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   atlas = image.threshold_img(atlas, "99.5%")
# atlas has shape ['x', 'y', 'z', 'region'] = (91, 109, 91, 200)

# %%
# atlas = image.load_img("HCP_PTN1200/groupICA/groupICA_3T_HCP1200_MSMAll_d100.ica/melodic_IC_sum.nii.gz")
# atlas = image.threshold_img(atlas, "99.5%") 
# print("atlas has shape", ["x", "y", "z", "region"], "=", atlas.shape)

# fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
# plotting.plot_prob_atlas(atlas, colorbar=True, draw_cross=False, axes=axs)
# axs.set_title("Map of Brain Regions")

# %%
#plotting connections on the brain
atlas_coords = plotting.find_probabilistic_atlas_cut_coords(atlas)
atlas_coords = np.array(atlas_coords)

# %%
def euclidean(point1, point2):
    distance = 0
    for i in range(len(point1)):
        distance += (point1[i] - point2[i]) ** 2
    return (distance) ** 0.5

# %%
def find_closest_point(atlas_coords, reference_point):
    # indices = [i for k,v in rois.items() for i, coord in enumerate(atlas_coords) if np.all(np.isclose(coord, v, rtol=1))]
    # if len(indices) == 0:
        # return None
    dist = np.inf
    closest_idx = None
    points=[]
    for idx in range(len(atlas_coords)):
        i = atlas_coords[idx]
        curr_dist = euclidean(reference_point, i)
        # dist.append(curr_dist)
        # points.append(i)
        # closest_idx.append(idx)
        if curr_dist < dist:
            dist = curr_dist
            closest_point = i
            closest_idx = idx
    # dist = sorted(zip(dist, points))[:10]
    # dist2 = sorted(zip(dist, closest_idx))[:10]
    
    print(dist, closest_point)
    return closest_idx

# %%
rois = {
    "Left M1": [-38, -24, 62],
    "Right M1": [34, -22, 62],
    "Left SMA" : [-8, 0, 54],
    "Right SMA" : [8, 0, 54],
    "Left PMd": [-16, -20, 48],
    "Right PMd": [34, -8, 52]}

# %%
all_points = set()
for k, v in rois.items():
    print(f"Closest point to {k}:")
    closest = find_closest_point(atlas_coords, v)
    all_points.add(closest)
# Out:
# Closest point to Left M1:
# 6.508918785949374 [-42.95098844 -24.68496559  57.8305205 ]
# Closest point to Right M1:
# 11.485082596078373 [ 44.26393131 -21.37248228  56.88482085]
# Closest point to Left SMA:
# 13.664893703066346 [-2.23353823  4.34613776 65.60122084]
# Closest point to Right SMA:
# 16.068682059114725 [-2.23353823  4.34613776 65.60122084]
# Closest point to Left PMd:
# 18.29657020959966 [-21.41821055 -28.96570539  63.00078674]
# Closest point to Right PMd:
# 17.55087014717411 [ 44.26393131 -21.37248228  56.88482085]

# %%
all_points
# Out:
# {42, 47, 54, 64}

# %%
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
selected_regions = image.index_img(atlas, list(all_points))
plotting.plot_prob_atlas(selected_regions, colorbar=True, draw_cross=False, axes=axs, display_mode="z")
axs.set_title("Map of Brain Regions")
# Out:
# Text(0.5, 1.0, 'Map of Brain Regions')

# %%
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
selected_regions = image.index_img(atlas, list(all_points)[:1])
plotting.plot_prob_atlas(selected_regions, colorbar=True, draw_cross=False, axes=axs)
axs.set_title("Map of Brain Regions")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
#       2 selected_regions = image.index_img(atlas, list(all_points)[:1])
# ----> 3 plotting.plot_prob_atlas(selected_regions, colorbar=True, draw_cross=False, axes=axs)
#       4 axs.set_title("Map of Brain Regions")
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/nilearn/plotting/img_plotting.py:1263, in plot_prob_atlas(maps_img, bg_img, view_type, threshold, linewidths, cut_coords, output_file, display_mode, figure, axes, title, annotate, draw_cross, black_bg, dim, colorbar, cmap, vmin, vmax, alpha, radiological, **kwargs)
#    1259 # Create a colormap from color list to feed display
#    1260 cmap = LinearSegmentedColormap.from_list(
#    1261     "segmented colors", color_list, n_maps + 1
#    1262 )
# -> 1263 display._show_colorbar(cmap, mpl.colors.Normalize(1, n_maps + 1))
#    1264 tick_locator = mpl.ticker.MaxNLocator(nbins=10)
#    1265 display.locator = tick_locator
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/nilearn/plotting/displays/_slicers.py:553, in BaseSlicer._show_colorbar(self, cmap, norm, cbar_vmin, cbar_vmax, threshold)
#     550 bounds = np.linspace(cbar_vmin, cbar_vmax, our_cmap.N)
#     552 # some colormap hacking
# --> 553 cmaplist = [our_cmap(i) for i in range(our_cmap.N)]
#     554 transparent_start = int(norm(-offset, clip=True) * (our_cmap.N - 1))
#     555 transparent_stop = int(norm(offset, clip=True) * (our_cmap.N - 1))
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/matplotlib/colors.py:739, in Colormap.__call__(self, X, alpha, bytes)
#     716 def __call__(self, X, alpha=None, bytes=False):
#     717     r"""
#     718     Parameters
#     719     ----------
#    (...)
#     737     RGBA values with a shape of ``X.shape + (4, )``.
#     738     """
# --> 739     rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     740     if not np.iterable(X):
#     741         rgba = tuple(rgba)
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/matplotlib/colors.py:770, in Colormap._get_rgba_and_mask(self, X, alpha, bytes)
#     745 r"""
#     746 Parameters
#     747 ----------
#    (...)
#     767     Boolean array with True where the input is ``np.nan`` or masked.
#     768 """
#     769 if not self._isinit:
# --> 770     self._init()
#     772 xa = np.array(X, copy=True)
#     773 if not xa.dtype.isnative:
#     774     # Native byteorder is faster.
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/matplotlib/colors.py:1063, in LinearSegmentedColormap._init(self)
#    1061 def _init(self):
#    1062     self._lut = np.ones((self.N + 3, 4), float)
# -> 1063     self._lut[:-3, 0] = _create_lookup_table(
#    1064         self.N, self._segmentdata['red'], self._gamma)
#    1065     self._lut[:-3, 1] = _create_lookup_table(
#    1066         self.N, self._segmentdata['green'], self._gamma)
#    1067     self._lut[:-3, 2] = _create_lookup_table(
#    1068         self.N, self._segmentdata['blue'], self._gamma)
#
# File ~/.conda/envs/capstone/lib/python3.13/site-packages/matplotlib/colors.py:656, in _create_lookup_table(N, data, gamma)
#     653 y1 = adata[:, 2]
#     655 if x[0] != 0. or x[-1] != 1.0:
# --> 656     raise ValueError(
#     657         "data mapping points must start with x=0 and end with x=1")
#     658 if (np.diff(x) < 0).any():
#     659     raise ValueError("data mapping points must have x in increasing order")
#
# ValueError: data mapping points must start with x=0 and end with x=1

# %%
#finding the names of the ROIs

from nilearn import image, plotting
from atlasreader.atlasreader import read_atlas_peak

"""
available reference atlases
---------------------------
    "aal",
    "aicha",
    "desikan_killiany",
    "destrieux",
    "harvard_oxford",
    "juelich",
    "marsatlas",
    "neuromorphometrics",
    "talairach_ba",
    "talairach_gyrus",
 """
brain_region = []
print("BRAIN REGIONS:\n--------------")
for atlas_coord in atlas_coords:
    region = read_atlas_peak("harvard_oxford", atlas_coord)
    print(region)
    brain_region += [region]
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data
#
# BRAIN REGIONS:
# --------------
# [[np.float64(62.0), 'Right_Occipital_Pole']]
# [[np.float64(50.0), 'Right_Lateral_Occipital_Cortex_superior_division'], [np.float64(30.0), 'Right_Angular_Gyrus']]
# [[np.float64(56.0), 'Right_Lateral_Occipital_Cortex_inferior_division'], [np.float64(14.0), 'Right_Occipital_Pole']]
# [[np.float64(54.0), 'Left_Cuneal_Cortex'], [np.float64(9.0), 'Right_Cuneal_Cortex']]
# [[np.float64(81.0), 'Left_Supramarginal_Gyrus_anterior_division'], [np.float64(6.0), 'Left_Supramarginal_Gyrus_posterior_division']]
# [[np.float64(85.0), 'Right_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(66.0), 'Right_Supramarginal_Gyrus_posterior_division'], [np.float64(14.0), 'Right_Angular_Gyrus']]
# [[np.float64(68.0), 'Right_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(72.0), 'Left_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(49.0), 'Right_Precuneous_Cortex'], [np.float64(30.0), 'Left_Precuneous_Cortex']]
# [[np.float64(47.0), 'Right_Occipital_Fusiform_Gyrus'], [np.float64(26.0), 'Right_Lingual_Gyrus']]
# [[np.float64(46.0), 'Left_Angular_Gyrus'], [np.float64(22.0), 'Left_Supramarginal_Gyrus_posterior_division'], [np.float64(7.0), 'Left_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(45.0), 'Left_Lateral_Occipital_Cortex_superior_division'], [np.float64(17.0), 'Left_Occipital_Pole']]
# [[np.float64(61.0), 'Left_Lateral_Occipital_Cortex_superior_division'], [np.float64(9.0), 'Left_Superior_Parietal_Lobule']]
# [[np.float64(39.0), 'Left_Precuneous_Cortex'], [np.float64(29.0), 'Right_Precuneous_Cortex'], [np.float64(5.0), 'Left_Cuneal_Cortex']]
# [[np.float64(47.0), 'Right_Occipital_Pole'], [np.float64(6.0), 'Right_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(64.0), 'Right_Intracalcarine_Cortex']]
# [[np.float64(43.0), 'Right_Lateral_Occipital_Cortex_superior_division'], [np.float64(5.0), 'Right_Precuneous_Cortex']]
# [[np.float64(17.0), 'Left_Occipital_Pole'], [np.float64(13.0), 'Right_Occipital_Pole'], [np.float64(13.0), 'Left_Intracalcarine_Cortex'], [np.float64(9.0), 'Left_Lingual_Gyrus'], [np.float64(9.0), 'Right_Intracalcarine_Cortex'], [np.float64(7.0), 'Left_Supracalcarine_Cortex'], [np.float64(6.0), 'Right_Lingual_Gyrus'], [np.float64(5.0), 'Right_Supracalcarine_Cortex']]
# [[np.float64(75.0), 'Left_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(37.0), 'Left_Postcentral_Gyrus'], [np.float64(33.0), 'Left_Precentral_Gyrus']]
# [[np.float64(11.0), 'Left_Superior_Frontal_Gyrus'], [np.float64(8.0), 'Right_Superior_Frontal_Gyrus'], [np.float64(7.0), 'Left_Frontal_Pole'], [np.float64(5.0), 'Right_Frontal_Pole']]
# [[np.float64(63.0), 'Right_Supramarginal_Gyrus_anterior_division'], [np.float64(9.0), 'Right_Postcentral_Gyrus']]
# [[np.float64(68.0), 'Right_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(71.0), 'Left_Occipital_Pole']]
# [[np.float64(82.0), 'Left_Frontal_Pole']]
# [[np.float64(56.0), 'Right_Superior_Parietal_Lobule'], [np.float64(17.0), 'Right_Postcentral_Gyrus']]
# [[np.float64(56.0), 'Left_Occipital_Pole']]
# [[np.float64(25.0), 'Left_Middle_Temporal_Gyrus_posterior_division'], [np.float64(18.0), 'Left_Superior_Temporal_Gyrus_posterior_division'], [np.float64(14.0), 'Left_Middle_Temporal_Gyrus_anterior_division'], [np.float64(9.0), 'Left_Superior_Temporal_Gyrus_anterior_division']]
# [[np.float64(63.0), 'Right_Lateral_Occipital_Cortex_inferior_division'], [np.float64(6.0), 'Right_Lateral_Occipital_Cortex_superior_division']]
# [[np.float64(35.0), 'Right_Supramarginal_Gyrus_posterior_division'], [np.float64(29.0), 'Right_Angular_Gyrus']]
# [[np.float64(45.0), 'Right_Occipital_Pole']]
# [[np.float64(77.0), 'Left_Frontal_Pole']]
# [[np.float64(44.0), 'Left_Lateral_Occipital_Cortex_superior_division'], [np.float64(17.0), 'Left_Superior_Parietal_Lobule']]
# [[np.float64(47.0), 'Left_Postcentral_Gyrus'], [np.float64(28.0), 'Left_Supramarginal_Gyrus_anterior_division']]
# [[np.float64(39.0), 'Left_Paracingulate_Gyrus'], [np.float64(33.0), 'Left_Frontal_Pole']]
# [[np.float64(33.0), 'Left_Inferior_Frontal_Gyrus_pars_opercularis'], [np.float64(29.0), 'Left_Inferior_Frontal_Gyrus_pars_triangularis']]
# [[np.float64(46.0), 'Right_Juxtapositional_Lobule_Cortex_(formerly_Supplementary_Motor_Cortex)'], [np.float64(19.0), 'Left_Juxtapositional_Lobule_Cortex_(formerly_Supplementary_Motor_Cortex)']]
# [[np.float64(26.0), 'Right_Occipital_Fusiform_Gyrus'], [np.float64(25.0), 'Right_Occipital_Pole'], [np.float64(13.0), 'Right_Lingual_Gyrus']]
# [[np.float64(43.0), 'Right_Middle_Frontal_Gyrus'], [np.float64(21.0), 'Right_Inferior_Frontal_Gyrus_pars_opercularis'], [np.float64(8.0), 'Right_Inferior_Frontal_Gyrus_pars_triangularis']]
# [[np.float64(53.0), 'Left_Postcentral_Gyrus'], [np.float64(13.0), 'Left_Precentral_Gyrus']]
# [[0, 'no_label']]
# [[np.float64(48.0), 'Right_Postcentral_Gyrus'], [np.float64(8.0), 'Right_Precentral_Gyrus']]
# [[np.float64(48.0), 'Left_Inferior_Frontal_Gyrus_pars_triangularis'], [np.float64(27.0), 'Left_Frontal_Pole'], [np.float64(7.0), 'Left_Middle_Frontal_Gyrus']]
# [[np.float64(29.0), 'Right_Planum_Temporale'], [np.float64(13.0), 'Right_Superior_Temporal_Gyrus_posterior_division']]
# [[0, 'no_label']]
# [[np.float64(43.0), 'Right_Precentral_Gyrus'], [np.float64(11.0), 'Left_Precentral_Gyrus'], [np.float64(7.0), 'Right_Postcentral_Gyrus']]
# [[np.float64(76.0), 'Right_Frontal_Pole']]
# [[np.float64(5.0), 'Right_Occipital_Fusiform_Gyrus']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(48.0), 'Right_Hippocampus'], [np.float64(35.0), 'Right_Amygdala']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(83.0), 'Right_Caudate'], [np.float64(16.0), 'Right_Lateral_Ventricle']]
# [[0, 'no_label']]
# [[np.float64(99.0), 'Left_Putamen']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Left_Thalamus']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Left_Putamen']]
# [[0, 'no_label']]
# [[np.float64(41.0), 'Brain-Stem']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Right_Putamen']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(94.0), 'Left_Caudate'], [np.float64(5.0), 'Left_Lateral_Ventrical']]
# [[np.float64(100.0), 'Brain-Stem']]
# [[np.float64(100.0), 'Brain-Stem']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Brain-Stem']]
# [[np.float64(100.0), 'Right_Thalamus']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Brain-Stem']]
# [[0, 'no_label']]
# [[0, 'no_label']]
# [[np.float64(100.0), 'Brain-Stem']]
# [[np.float64(97.0), 'Brain-Stem']]
# [[np.float64(99.0), 'Left_Thalamus']]
# [[np.float64(96.0), 'Right_Thalamus']]
# [[np.float64(92.0), 'Brain-Stem']]
# [[0, 'no_label']]
# [[0, 'no_label']]

# %%
#select the correct region with largest probability given from the library
brain_region = [
    max(inner_list, key=lambda x: x[0])[-1] if inner_list else None for inner_list in brain_region
]
np.array(brain_region)[list(all_points)]
# Out:
# array(['Left_Postcentral_Gyrus', 'Right_Postcentral_Gyrus',
#        'Right_Juxtapositional_Lobule_Cortex_(formerly_Supplementary_Motor_Cortex)'],
#       dtype='<U73')
